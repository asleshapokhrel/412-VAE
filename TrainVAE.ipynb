# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/412-VAE/412-VAE
# Out:
# /content/drive/MyDrive/412-VAE/412-VAE

# %%
# !bash ./Anaconda3-2020.11-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# # All requested packages already installed.
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Anaconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Anaconda3: /usr/local

# %%
# %%bash
# export NMN=$PWD
# conda env create -f environment.yml
# source activate sysgen
# pip install -e .
# Out:
# Obtaining file:///content/drive/My%20Drive/412-VAE/412-VAE
# ...
#   Attempting uninstall: nmn-iwp
#     Found existing installation: nmn-iwp 0.1
#     Uninstalling nmn-iwp-0.1:
#       Successfully uninstalled nmn-iwp-0.1
#   Running setup.py develop for nmn-iwp
# ...
# CondaValueError: prefix already exists: /usr/local/envs/sysgen

# %%
# %%bash
# source activate sysgen
#
# python
# import sys
# # some simple python commands
# sys.path.append('/usr/local/lib/python3.6/site-packages')
# print(sys.path)
#
# print("Python version")
# print(sys.version)
# Out:
# ['', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/My Drive/412-VAE/412-VAE', '/usr/local/lib/python3.6/site-packages']
# Python version
# 3.6.13 |Anaconda, Inc.| (default, Feb 23 2021, 21:15:04)
# [GCC 7.3.0]

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
# %%bash
# source activate sysgen
# dos2unix scripts/train/vanilla_vae.sh
# chmod +x scripts/train/vanilla_vae.sh
# export NMN=/content/drive/MyDrive/412-VAE/412-VAE
#
# scripts/train/vanilla_vae.sh
# Out:
# dos2unix: converting file scripts/train/vanilla_vae.sh to Unix format...
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/412-VAE/412-VAE/scripts/train_vanilla.py", line 24, in <module>
#     train(vanilla_vae, train_dataset, 10, 128)
#   File "/content/drive/MyDrive/412-VAE/412-VAE/scripts/train.py", line 24, in train
#     loss = model.loss_function(model.forward(batch))['loss']
#   File "/content/drive/My Drive/412-VAE/412-VAE/src/models/BaseVae.py", line 151, in forward
#     return  [self.decode(z), input, mu, log_var]
#   File "/content/drive/My Drive/412-VAE/412-VAE/src/models/BaseVae.py", line 103, in decode
#     decoder_input = self.decoder_input(z).view(-1, 512, 2, 2)
# RuntimeError: shape '[-1, 512, 2, 2]' is invalid for input of size 3072

# %%
# %%bash
# source activate sysgen
# dos2unix scripts/train/beta_vae.sh
# chmod +x scripts/train/beta_vae.sh
# export NMN=/content/drive/MyDrive/412-VAE/412-VAE
#
# scripts/train/beta_vae.sh
# Out:
# dos2unix: converting file scripts/train/beta_vae.sh to Unix format...
#   File "/content/drive/MyDrive/412-VAE/412-VAE/scripts/train_beta.py", line 4
#     import src.PreProcessing.preprocessing import *
#                                                 ^
# SyntaxError: invalid syntax
