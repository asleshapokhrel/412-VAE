# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/412-VAE
# Out:
# /content/drive/MyDrive/412-VAE

# %%
# !bash ./Anaconda3-2020.11-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py_0
#     - anaconda-client==1.7.2=py38_0
#     - anaconda-navigator==1.10.0=py38_0
#     - anaconda-project==0.8.4=py_0
#     - anaconda==2020.11=py38_0
#     - argh==0.26.2=py38_0
#     - argon2-cffi==20.1.0=py38h7b6447c_1
#     - asn1crypto==1.4.0=py_0
#     - astroid==2.4.2=py38_0
#     - astropy==4.0.2=py38h7b6447c_0
#     - async_generator==1.10=py_0
#     - atomicwrites==1.4.0=py_0
#     - attrs==20.3.0=pyhd3eb1b0_0
#     - autopep8==1.5.4=py_0
#     - babel==2.8.1=pyhd3eb1b0_0
#     - backcall==0.2.0=py_0
#     - backports.functools_lru_cache==1.6.1=py_0
#     - backports.shutil_get_terminal_size==1.0.0=py38_2
#     - backports.tempfile==1.0=py_1
#     - backports.weakref==1.0.post1=py_1
#     - backports==1.0=py_2
# ...

# %%
# %%bash
# export NMN=$PWD
# conda env create -f environment.yml
# source activate sysgen
# pip install -e .
# Out:
# ...
# Solving environment: ...working... done
#
# ...
# cython-0.29.23       | 1.9 MB    | ########## | 100%
# blinker-1.4          | 22 KB     | ########## | 100%
# protobuf-3.14.0      | 303 KB    | ########## | 100%
# pyopenssl-20.0.1     | 49 KB     | ########## | 100%
# lame-3.100           | 323 KB    | ########## | 100%
# gnutls-3.6.15        | 1.0 MB    | ########## | 100%
# pyasn1-0.4.8         | 57 KB     | ########## | 100%
# python-3.6.13        | 29.7 MB   | ########## | 100%
# zstd-1.4.9           | 480 KB    | ########## | 100%
# coverage-5.5         | 258 KB    | ########## | 100%
# grpcio-1.36.1        | 1.9 MB    | ########## | 100%
# libprotobuf-3.14.0   | 2.0 MB    | ########## | 100%
# cachetools-4.2.1     | 13 KB     | ########## | 100%
# pyjwt-1.7.1          | 33 KB     | ########## | 100%
# pyyaml-5.1.2         | 179 KB    | ########## | 100%
# ffmpeg-4.3           | 9.9 MB    | ########## | 100%
# libidn2-2.3.0        | 86 KB     | ########## | 100%
# ...

# %%
# %%bash
# source activate sysgen
#
# python
# import sys
# # some simple python commands
# sys.path.append('/usr/local/lib/python3.6/site-packages')
# print(sys.path)
#
# print("Python version")
# print(sys.version)
# Out:
# ['', '/env/python', '/usr/local/envs/sysgen/lib/python36.zip', '/usr/local/envs/sysgen/lib/python3.6', '/usr/local/envs/sysgen/lib/python3.6/lib-dynload', '/usr/local/envs/sysgen/lib/python3.6/site-packages', '/content/drive/MyDrive/412-VAE', '/usr/local/lib/python3.6/site-packages']
# Python version
# 3.6.13 |Anaconda, Inc.| (default, Feb 23 2021, 21:15:04)
# [GCC 7.3.0]

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 0s (3,580 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# %%bash
# source activate sysgen
# dos2unix scripts/train/vanilla_vae.sh
# chmod +x scripts/train/vanilla_vae.sh
# export NMN=/content/drive/MyDrive/412-VAE
#
# scripts/train/vanilla_vae.sh
# Out:
# dos2unix: scripts/train/vanilla_vae.sh: No such file or directory
# dos2unix: Skipping scripts/train/vanilla_vae.sh, not a regular file.
# chmod: cannot access 'scripts/train/vanilla_vae.sh': No such file or directory
# bash: line 6: train/vanilla_vae.sh: No such file or directory

# %%
# %%bash
# source activate sysgen
# dos2unix scripts/train/beta_vae.sh
# chmod +x scripts/train/beta_vae.sh
# export NMN=/content/drive/MyDrive/412-VAE
#
# scripts/train/beta_vae.sh
# Out:
# dos2unix: scripts/train/beta_vae.sh: No such file or directory
# dos2unix: Skipping scripts/train/beta_vae.sh, not a regular file.
# chmod: cannot access 'scripts/train/beta_vae.sh': No such file or directory
# bash: line 6: scripts/train/beta_vae.sh: No such file or directory
